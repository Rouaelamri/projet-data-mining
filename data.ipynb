# %%
import tweepy
import pandas as pd
import matplotlib.pyplot as plt

# %%
consumer_key = "Tippg04Ns8bfIZtE3uMprKEym" 
consumer_secret = "qHjBkD4CBX67rHPenKu96c7W5Tsv59t9BGBVsm0pXM0oLatOS8"
access_key= "1328070400136400905-ZOCtds4L0DD3LqMJ2r9rZHSyAi75Xu"
access_secret = "qX3pBBD42A1dAZDPXx2DGcH0T0hcr4e5Oxw40YwR9wTnc"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
twitter_data_analysis = pd.DataFrame(columns = ['tweetID','tweetText','tweetRetweetCt','tweetFavoriteCt','tweetSource','tweetCreated'])
tweets = tweepy.Cursor(api. user_timeline , id="twitter").items( 15000)

# Iterate and print tweets
i=0
for tweet in tweets:
    twitter_data_analysis.loc[i,"tweetID"] = tweet.id
    twitter_data_analysis.loc[i,"tweetText"] = tweet.text
    twitter_data_analysis.loc[i,"tweetRetweetCt"] = tweet.retweet_count
    twitter_data_analysis.loc[i,"tweetFavoriteCt"] = tweet.favorite_count
    twitter_data_analysis.loc[i,"tweetSource"] = tweet.source
    twitter_data_analysis.loc[i,"tweetCreated"] = tweet.created_at
    i+=1

# %%
import csv

twitter_data_analysis.to_csv('twitter_data_analysis.csv',index = False)
twitter_data_analysis.head(40)
# Out:
#                 tweetID                                          tweetText  \
# 0   1334542969530183683                                   2020 in one word
# 1   1334540220642041862  @Astro_AJC this is what cuffing season means t...
# 2   1334540220591648770                            @un3asyy 2 is also cute
# 3   1333921747691769856                     @DeePeeArts you're all amazing
# 4   1329561340596391936  RT @shesooosaddity: if you had a twitter befor...
# 5   1329217044391342082                                   @CloudNaii 40404
# 6   1329216472711827458    @issahairplug drink water replaced good morning
# 7   1329107688916135936        @Ne_ThatGuy we're taking oomf to the Fleets
# 8   1329104797727940612  @_JusJust_ remember "I dedicate my 500th Tweet...
# 9   1329104643062902788                       @ambr_ncole they're tourists
# 10  1329101613940797441         @PhallonXOXO proof you're doing it right 😌
# 11  1328838299419627525  some of you hating...\n\nbut we see you Fleeti...
# 12  1328684389388185600  That thing you didn’t Tweet but wanted to but ...
# 13  1328426768009736192                           @quakerraina this is art
# 14  1328411214351831044                     @tsm560 aren't we all six feet
# 15  1328411086308200449   @muharikah this Tweet just graduated with honors
# 16  1328091011436982272  @badgirIkiki saw it, love it, can't wait for t...
# 17  1327102544942870528         RT @theDapperilla: https://t.co/vAQvG5H74u
# 18  1323314485705297926                                            breathe
# 19  1323305871728906241                      @sexyvamplre apology accepted
# 20  1320826934079705088                                     @DaReal2ET H2🌑
# 21  1320825824879255556                           @Theghostgaming_ THIRSTY
# 22  1320825326407196672                    @AndrewJacklin looking hydrated
# 23  1320825326365265920                    @litcapital the moon will share
# 24  1320824522166120449                   @dog_vegano bark among the stars
# 25  1320824397184274439           @Sliim_sadie rubber ducky knew all along
# 26  1320822556614676480                 If the moon can hydrate so can you
# 27  1319006269785755648  Reading an article before Retweeting it? That’...
# 28  1318900658217648128  Hey everyone, we made a temporary change to th...
# 29  1318645661475180546  RT @lestheprez: Me seeing my Twitter friends I...
# 30  1317227243064774658              RT @virafied: https://t.co/nA63eHXgx1
# 31  1315777146355417089                               @lunancts dedication
# 32  1315670626175258630          @starheal not a single person on this app
# 33  1314675188290772992                @couribruv but was it a good Tweet?
# 34  1314674165186789379                           @wowimnothere checks out
# 35  1314358633921236995                    @KaiDavisPoet you forgot one: 😂
# 36  1314353837994463232  @ImBrittanyEvans mutual acknowledgment of good...
# 37  1314353837780750337                @SharjeelKd https://t.co/TMDtvGOtMn
# 38  1313584258905186305  @_micawave how it started          it never en...
# 39  1313544965339918339        @issataiii just make sure your DMs are open
#
#    tweetRetweetCt tweetFavoriteCt      tweetSource         tweetCreated
# 0           22834          266856         Sprinklr  2020-12-03 17:00:13
# 1              50            3730         Sprinklr  2020-12-03 16:49:17
# 2               9             113         Sprinklr  2020-12-03 16:49:17
# 3               2              37         Sprinklr  2020-12-01 23:51:42
# 4           35042               0         Sprinklr  2020-11-19 23:05:00
# 5              43             525         Sprinklr  2020-11-19 00:16:53
# 6              13             117         Sprinklr  2020-11-19 00:14:37
# 7              40             447         Sprinklr  2020-11-18 17:02:21
# 8             483            2548         Sprinklr  2020-11-18 16:50:52
# 9              52             414         Sprinklr  2020-11-18 16:50:15
# 10              6             275         Sprinklr  2020-11-18 16:38:12
# 11          35872          288880         Sprinklr  2020-11-17 23:11:53
# 12          11705           76313         Sprinklr  2020-11-17 13:00:18
# 13              4             302         Sprinklr  2020-11-16 19:56:37
# 14              3              60         Sprinklr  2020-11-16 18:54:48
# 15             27             196         Sprinklr  2020-11-16 18:54:18
# 16             51            2028         Sprinklr  2020-11-15 21:42:26
# 17          56842               0  Twitter Web App  2020-11-13 04:14:37
# 18          48082          241484         Sprinklr  2020-11-02 17:22:14
# 19             24             672         Sprinklr  2020-11-02 16:48:00
# 20              6             461         Sprinklr  2020-10-26 20:37:35
# 21              7             149         Sprinklr  2020-10-26 20:33:11
# 22              9             384         Sprinklr  2020-10-26 20:31:12
# 23              7             331         Sprinklr  2020-10-26 20:31:12
# 24             46            1545         Sprinklr  2020-10-26 20:28:00
# 25              8             571         Sprinklr  2020-10-26 20:27:30
# 26          15574          100050         Sprinklr  2020-10-26 20:20:11
# 27           3052           12324         Sprinklr  2020-10-21 20:02:55
# 28          48702           59330         Sprinklr  2020-10-21 13:03:15
# 29          30879               0  Twitter Web App  2020-10-20 20:09:59
# 30          44571               0  Twitter Web App  2020-10-16 22:13:42
# 31            227            1426         Sprinklr  2020-10-12 22:11:32
# 32            185            2159         Sprinklr  2020-10-12 15:08:15
# 33            773           35168         Sprinklr  2020-10-09 21:12:45
# 34              5              93         Sprinklr  2020-10-09 21:08:41
# 35              4              97         Sprinklr  2020-10-09 00:14:52
# 36              7              52         Sprinklr  2020-10-08 23:55:49
# 37              3              49         Sprinklr  2020-10-08 23:55:49
# 38            478            4523         Sprinklr  2020-10-06 20:57:47
# 39              1              60         Sprinklr  2020-10-06 18:21:38

# %%
twitter_data_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3222 entries, 0 to 3221
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tweetID          3222 non-null   object
#  1   tweetText        3222 non-null   object
#  2   tweetRetweetCt   3222 non-null   object
#  3   tweetFavoriteCt  3222 non-null   object
#  4   tweetSource      3222 non-null   object
#  5   tweetCreated     3222 non-null   object
# dtypes: object(6)
# memory usage: 336.2+ KB

# %% [markdown]
# ## Pretraitement des Données

# %%
import re

# %%
for index, row in twitter_data_analysis.iterrows():
    err = row['tweetText']
    new0 = re.sub(r"http?:\/\/\S+","",err) #Removed the hyerlink
    new1 = re.sub(r"#\S+", "", new0)
    nw2 = re.sub(r"@\S+", "", new1)
    new3 = re.sub(r"\n+", "", new2)
    new4 = re.sub(r"RT+", "", new3) #Removed RT
    new5 = re.sub("hhh+", '', new4)
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    new6 = re.sub(emoji_pattern, "", new5)
    twitter_data_analysis.loc[index,'tweetText'] =new6

# %%
twitter_data_analysis.head(40)

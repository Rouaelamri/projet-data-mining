# %% [markdown]
# <h1 style="color:#9D8BC8;"> Projet Classification des tweets </h1>
# <h2 style="color:#C9BAEE;"> Réalisé par : Roua ELAMRI 3DNI 1</h2>

# %% [markdown]
# <h3 style="color:#7763A8;"> Introduction Générale </h3>

# %% [markdown]
# <p> Les postes publiés sur Twitter reflètent l’interaction d’utilisateurs avec les événements réels qui se déroulent dans le monde, comme les élections, les événements sportifs et culturels, les catastrophes naturelles, etc. </p>

# %% [markdown]
# <h3 style="color:#7763A8;"> Problématique </h3>
# <p>Ces événements réels ont un impact direct sur la quantité de tweets mises en ligne. Le suivi de ces événements sur Twitter est un défi audacieux pour les chercheurs, tout d’abord parce qu’un sujet sur Twitter est caractérisé par plusieurs termes qui peuvent changer dynamiquement où certains peuvent devenir moins utilisés et d’autres peuvent apparaître. Donc il est incontournable de trouver un moyen pour couvrir tous ces termes utilisés pendant le processus d’analyse.
# </p>

# %% [markdown]
# <h3 style="color:#7763A8;"> Solution proposée </h3>
# <p> Dans la cadre de ce projet nous proposons un modéle de classification des tweets afin de faciliter le suivi des actualités </p>

# %% [markdown]
# <h3 style="color:#7763A8;"> Réalisation </h3>
# <p> La premiére partie consiste a importer le Tweepy , pd et plt </p>
# <p> Tout d'abord, importons Tweepy et ajoutons nos propres informations d'authentification. </p>

# %%
import tweepy
import pandas as pd
import matplotlib.pyplot as plt

# %%
consumer_key = "Tippg04Ns8bfIZtE3uMprKEym" 
consumer_secret = "qHjBkD4CBX67rHPenKu96c7W5Tsv59t9BGBVsm0pXM0oLatOS8"
access_key= "1328070400136400905-ZOCtds4L0DD3LqMJ2r9rZHSyAi75Xu"
access_secret = "qX3pBBD42A1dAZDPXx2DGcH0T0hcr4e5Oxw40YwR9wTnc"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %% [markdown]
# <p> =>  Notre objectif consiste a collecter 10.000 tweets , on a eu recours a faire l extraction des tweets 3 fois
#     afin d'atteindre notre objectif. </p>

# %%
twitter_data_analysis = pd.DataFrame(columns = ['tweetID','tweetText','tweetRetweetCt','tweetFavoriteCt','tweetSource','tweetCreated'])
tweets = tweepy.Cursor(api.search, q="#", lang="en", since="2020-01-01").items(2400)

# Iterate and print tweets
i=0
for tweet in tweets:
    twitter_data_analysis.loc[i,"tweetID"] = tweet.id
    twitter_data_analysis.loc[i,"tweetText"] = tweet.text
    twitter_data_analysis.loc[i,"tweetRetweetCt"] = tweet.retweet_count
    twitter_data_analysis.loc[i,"tweetFavoriteCt"] = tweet.favorite_count
    twitter_data_analysis.loc[i,"tweetSource"] = tweet.source
    twitter_data_analysis.loc[i,"tweetCreated"] = tweet.created_at
    i+=1

# %%
import csv

twitter_data_analysis.to_csv('twitter_data_analysis.csv',index = False)
twitter_data_analysis.head(40)
# Out:
#                 tweetID                                          tweetText  \
# 0   1336732652532064261  RT @SmithHelmut: My pick for the last lecture ...
# 1   1336732652519493636  @TheManCalledDon Hopefully Arthur Blank's hiri...
# 2   1336732652519436290  RT @Nadalchukwu: We are scoring nothing less t...
# 3   1336732652515287045     well cuz i want dior 👀 https://t.co/4ldtDn3y6A
# 4   1336732652502708225  RT @SciissorBlades: "Rightio then, i'll be hav...
# 5   1336732652494344192                                     ok im done sry
# 6   1336732652485939202  RT @ceodaegu: guys,,,PLEASE? https://t.co/lEWu...
# 7   1336732652481732610  RT @MrGee54: Oh shit. The Derriere Detective i...
# 8   1336732652473356291  @HoussemAouarrr @CFC_strongray @CFCElIis @KZN2...
# 9   1336732652473348096  RT @ABAonline: For advice on all the latest ap...
# 10  1336732652469067777                 @KOT4Q to the bulls for satoransky
# ...

# %%
twitter_data = pd.DataFrame(columns = ['tweetID','tweetText','tweetRetweetCt','tweetFavoriteCt','tweetSource','tweetCreated'])
tweets = tweepy.Cursor(api.search, q="#", lang="en", since="2019-01-01").items(2400)

# Iterate and print tweets
i=0
for tweet in tweets:
    twitter_data.loc[i,"tweetID"] = tweet.id
    twitter_data.loc[i,"tweetText"] = tweet.text
    twitter_data.loc[i,"tweetRetweetCt"] = tweet.retweet_count
    twitter_data.loc[i,"tweetFavoriteCt"] = tweet.favorite_count
    twitter_data.loc[i,"tweetSource"] = tweet.source
    twitter_data.loc[i,"tweetCreated"] = tweet.created_at
    i+=1

# %%
twitter_da = pd.DataFrame(columns = ['tweetID','tweetText','tweetRetweetCt','tweetFavoriteCt','tweetSource','tweetCreated'])
tweets = tweepy.Cursor(api.search, q="#", lang="en", since="2019-01-01").items(2400)

# Iterate and print tweets
i=0
for tweet in tweets:
    twitter_da.loc[i,"tweetID"] = tweet.id
    twitter_da.loc[i,"tweetText"] = tweet.text
    twitter_da.loc[i,"tweetRetweetCt"] = tweet.retweet_count
    twitter_da.loc[i,"tweetFavoriteCt"] = tweet.favorite_count
    twitter_da.loc[i,"tweetSource"] = tweet.source
    twitter_da.loc[i,"tweetCreated"] = tweet.created_at
    i+=1

# %%
twitter_da.to_csv('twitter_da.csv',index = False)
twitter_da.head(10)
# Out:
#                tweetID                                          tweetText  \
# 0  1336765607887446018  RT @PastPostcard: We had a drive round tonight...
# 1  1336765607887433734  I didn’t have “Cartoon Network campaigning aga...
# 2  1336765607828729858  RT @Ask4Capital: Need money for your business ...
# 3  1336765607824461825  @Kadi_R1 You're just scared!!! 😂😂I would beat ...
# 4  1336765607816159235  RT @nwankwoesq: The Stage is getting set for A...
# 5  1336765607816130561                                         I love red
# 6  1336765607807741957  @lornarichardson ‘Are puns’??? Such as more like.
# 7  1336765607799353352  RT @pvpoke: Good morning, \n@PokemonGoApp\n! C...
# 8  1336765607795175426         @NotVisionFN @SequenceSect build pullout 😍
# 9  1336765607795167232  RT @myunclesmemes: Takes skill https://t.co/xB...
#
#   tweetRetweetCt tweetFavoriteCt          tweetSource         tweetCreated
# 0              2               0   Twitter for iPhone  2020-12-09 20:12:11
# ...

# %% [markdown]
# <p> Aprés l extraction nous avons eu 3 fichiers csv contenat plus que 3000 tweets chacun et puis
# nous avons regroupé les 3 CSV dans un seul csv ' combined_csv.csv' afin d'atteindre plus que 10000 tweets </p>

# %%
from glob import glob

# %%
import glob

extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# <h2 style="color:#7763A8;" > Prétraitement des données </h2>
# <p> Cette partie consiste a nettoyer les données , Enlever les @ , les symboles ,  les emojis , les flags </p>

# %%
import re
for index, row in combined_csv.iterrows():
    err = row['tweetText']
    new0 = re.sub(r"http\S+", "", err)
    new1 = re.sub(r"#\S+", "", new0)
    new2 = re.sub(r"@\S+", "", new1)
    new3 = re.sub(r"\n+", "", new2)
    new4 = re.sub(r"RT+", "", new3)
    new5 = re.sub("hhh+", '', new4)
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    new6 = re.sub(emoji_pattern, "", new5)
    combined_csv.loc[index,'tweetText'] =new6

# %%
combined_csv.head(40)
# Out:
#                 tweetID                                          tweetText  \
# 0   1336765607887446018    My pick for the last lecture of global histo...
# 1   1336765607887433734   Hopefully Arthur Blank's hiring firm takes a ...
# 2   1336765607828729858    We are scoring nothing less than 3 goals tod...
# 3   1336765607824461825                             well cuz i want dior
# 4   1336765607816159235               "Rightio then, i'll be having that"
# 5   1336765607816130561                                     ok im done sry
# 6   1336765607807741957                                    guys,,,PLEASE?
# 7   1336765607799353352           Oh shit. The Derriere Detective is here
# 8   1336765607795175426                                       Laportes 3rd
# 9   1336765607795167232    For advice on all the latest aps and games y...
# 10  1336765607765635072                        to the bulls for satoransky
# 11  1336765607749046273    It's  of our   All you have to do  this post...
# ...

# %% [markdown]
# <p> La cellule suivante consiste à enregistrer les données nettoyés </p>

# %%
combined_csv.to_csv('cleaning_data.csv',index = False)

# %%
tweeter=pd.read_csv('cleaning_data.csv')
tweeter.head(5)
# Out:
#                tweetID                                          tweetText  \
# 0  1336765607887446018    My pick for the last lecture of global histo...
# 1  1336765607887433734   Hopefully Arthur Blank's hiring firm takes a ...
# 2  1336765607828729858    We are scoring nothing less than 3 goals tod...
# 3  1336765607824461825                             well cuz i want dior
# 4  1336765607816159235               "Rightio then, i'll be having that"
#
#    tweetRetweetCt  tweetFavoriteCt          tweetSource         tweetCreated
# 0               2                0   Twitter for iPhone  2020-12-09 20:12:11
# 1               0                0   Twitter for iPhone  2020-12-09 20:12:11
# 2              38                0  Twitter for Android  2020-12-09 20:12:11
# 3               0                0  Twitter for Android  2020-12-09 20:12:11
# 4               7                0  Twitter for Android  2020-12-09 20:12:11

# %% [markdown]
# <h2 style="color:#7763A8;"> Natural Language Toolkit  </h2>

# %% [markdown]
# <p> Natural Language Toolkit (NLTK) est une boîte-à-outil permettant la création de programmes
# pour l'analyse de texte. Cet ensemble a été créé à l'origine par Steven Bird et Edward Loper, en relation avec des cours de linguistique informatique à l'Université de Pennsylvanie en 2001.
# </p>

# %%
# !pip install nltk

# %% [markdown]
# <h2 style="color:#7763A8;"> Stop Words </h2>

# %% [markdown]
# <p> "Stop Words"
# Nous avons besoin des mots inutiles afin que les données soient davatange traduisibles pour l'ordinateur. En NLP, de telles données (des mots) sont qualifiées par stop words. Par conséquent, ces mots n'ont aucune signification pour nous, et nous souhaiterions les retirer. </p>

# %%
import nltk 
nltk.download('stopwords' )
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# <p> La cellule suivante permet d'afficher la liste des mots inutiles que stopwords va les supprimer  </p>

# %%
stopword = nltk.corpus.stopwords.words('english')
print(stopword)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %% [markdown]
# <h3 style="color:#7763A8;"> Tokenize mots et phrases avec NLTK</h3>

# %% [markdown]
# <p> La tokenisation est le processus par lequel une grande quantité de texte est divisée en parties plus petites appelées jetons .
#
# Le traitement du langage naturel est utilisé pour créer des applications telles que la classification de texte, le chatbot intelligent, l'analyse sentimentale, la traduction de la langue, etc. Il devient vital de comprendre le modèle dans le texte pour atteindre l'objectif susmentionné. Ces jetons sont très utiles pour trouver de tels modèles et sont considérés comme une étape de base pour la racine et la lemmatisation </p>

# %% [markdown]
# <p> Le Code suivant permet d'éliminer ces mots de notre texte  : </p>

# %%
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
ps = PorterStemmer() 
stemed_dataset=[]
for i in range(0,tweeter.shape[0]):
    stemmed_array=tweeter['tweetText'][i].split()
    stemmed=[ps.stem(word) for word in stemmed_array if not word in set(stopwords.words('english'))]
    stemmed=' '.join(stemmed)
    stemed_dataset.append(stemmed)
print(stemed_dataset[0:10])
# Out:
# ['My pick last lectur global history--th singl import chang world college…', "hope arthur blank' hire firm take close look names.", 'We score noth less 3 goal today.w realmadrid We gargantuan', 'well cuz want dior', '"rightio then, i\'ll that"', 'ok im done sri', 'guys,,,please?', 'Oh shit. the derrier detect', 'laport 3rd', 'for advic latest ap game kid using, explor free resourc creat']

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
X=cv.fit_transform(stemed_dataset)
print(X)
# Out:
#   (0, 3257)	1
#   (0, 3656)	1
#   (0, 2783)	1
#   (0, 2815)	1
#   (0, 2089)	1
#   (0, 2343)	1
#   (0, 4810)	1
#   (0, 4394)	1
#   (0, 2484)	1
#   (0, 982)	1
#   (0, 5340)	1
#   (0, 1102)	1
#   (1, 2379)	1
#   (1, 483)	1
#   (1, 725)	1
#   (1, 2338)	1
#   (1, 1891)	1
#   (1, 4748)	1
#   (1, 1072)	1
#   (1, 2919)	1
#   (1, 3274)	1
#   (2, 5213)	2
#   (2, 4225)	1
#   (2, 3377)	1
#   (2, 2834)	1
#   :	:
#   (7196, 636)	1
#   (7196, 1078)	1
#   (7196, 4874)	1
#   (7197, 542)	1
#   (7197, 1430)	1
#   (7197, 4626)	1
#   (7197, 3464)	1
#   (7197, 4898)	1
#   (7197, 572)	1
#   (7197, 2753)	1
#   (7197, 92)	1
#   (7197, 2905)	1
#   (7197, 2473)	1
#   (7197, 2401)	1
#   (7197, 5444)	1
#   (7197, 4559)	1
#   (7197, 343)	1
#   (7197, 3050)	1
#   (7197, 3269)	1
#   (7197, 1181)	1
#   (7198, 4089)	1
#   (7198, 2836)	1
#   (7198, 447)	1
#   (7198, 564)	1
#   (7199, 745)	1

# %% [markdown]
# <h2 style="color:#7763A8;"> Classification des tweets </h2>

# %% [markdown]
# <p> Clustering K-Means. </p>
# <p> Le nombre de clusters à former ainsi que le nombre de centres de gravité à générer.</p>

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,30):
    Kmeans=KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=10,random_state=0,verbose=True)
    Kmeans.fit(X)
wcss.append(Kmeans.inertia_)
# Out:
# Initialization complete
# Iteration 0, inertia 71727.0
# Iteration 1, inertia 56910.45625000005
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 100167.0
# Iteration 1, inertia 56910.45625000005
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 126705.0
# Iteration 1, inertia 56910.45625000005
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 164943.0
# Iteration 1, inertia 56910.45625000005
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 85959.0
# Iteration 1, inertia 56910.45625000005
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 150657.0
# Iteration 1, inertia 56910.45625000005
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 106911.0
# Iteration 1, inertia 56910.45625000005
# ...

# %%
true_k=30
Kmeans=KMeans(n_clusters=true_k,init='k-means++',n_init=1)
Kmeans.fit(X)
# Out:
# KMeans(n_clusters=30, n_init=1)

# %% [markdown]
# <p> Aprés fixer le nombre de clusters, le model KMeans va nous donner une idée générale sur les cluster avec une disaine de mots   puis afficher la liste des 30 clusters avec un echantillon representant les tweets de chaque cluster. </p>

# %%
print("Top terms per cluster:")
order_centroids = Kmeans.cluster_centers_.argsort()[:, ::-1]
terms = cv.get_feature_names()
for i in range(true_k):
    print("Cluster %d:" % i)
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind])
    print()
print("\n")
# Out:
# Top terms per cluster:
# Cluster 0:
#  none
#  center
#  paratha
#  deliveri
#  vika
#  home
#  كϝҽԃσσ
#  farmer
#  fantastic
#  faq
#
# Cluster 1:
#  thi
#  it
#  the
#  is
#  you
#  amp
#  trump
#  one
#  run
#  like
#
# Cluster 2:
#  you
#  like
#  miss
#  take
#  even
#  14
#  if
#  guy
#  lot
#  gum
#
# Cluster 3:
#  million
#  worth
#  run
#  month
#  can
#  afford
#  make
#  server
#  upon
#  damn
#
# Cluster 4:
#  get
#  amp
#  well
#  soon
#  busi
#  like
#  drug
#  send
#  stadium
#  ll
#
# Cluster 5:
#  thank
#  much
#  you
#  god
#  want
#  line
#  there
#  us
#  with
#  amp
#
# Cluster 6:
#  the
#  you
#  it
#  like
#  more
#  get
#  peopl
#  feel
#  we
#  time
#
# Cluster 7:
#  feel
#  detach
#  tauru
#  observation
#  day
#  set
#  more
#  fans
#  fantasi
#  fantastic
#
# Cluster 8:
#  artifici
#  go
#  too
#  hourli
#  grass
#  outsid
#  appreci
#  calmness
#  fill
#  to
#
# Cluster 9:
#  whatev
#  wh
#  كϝҽԃσσ
#  farmers
#  fantastic
#  faq
#  faqat
#  far
#  farage
# ...

# %%
i=0
j=0
while i<30:
    while True: 
        Y=cv.transform([stemed_dataset[j]])
        prediction=Kmeans.predict(Y)
        if i == prediction:
            print("tweet of cluster "+str(prediction)+tweeter.loc[j,"tweetText"]) 
            j=0
            break
        j+=1
    i+=1
# Out:
# tweet of cluster [0]  Vikas Paratha Center Home Delivery by none other  himself
# tweet of cluster [1]  Only 3.7K Left for 50K  let's Complete It Before 12!Comment One Word For This Upcoming project With Tagl…
# tweet of cluster [2]  “If You Are Working On Something That You Really Care About, You Don’t Have To Be Pushed. The Vision Pulls You.”
# tweet of cluster [3] Making millions upon millions a month and can't afford to run servers worth a damn.
# tweet of cluster [4]   Soccer is a sport where sane people run around to get a ball, and kick it away once they get it...
# tweet of cluster [5]  Thank you guys, it’s been a wild ride
# tweet of cluster [6]  My pick for the last lecture of global history--the single most important change in the world between when i was a college…
# tweet of cluster [7]A feeling of detachment sets you up for a day when observation... More for Taurus
# ...

# %% [markdown]
# <h2 style="color:#7763A8;" > Conclusion </h2>

# %% [markdown]
# <p> L'API de Twitter est extrêmement utile dans les applications d'exploration de données et peut fournir de vastes informations sur l'opinion publique. </p>
